# %%
# %matplotlib inline

import json
import logging
from pathlib import Path
import random
import tarfile
import tempfile
import warnings

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pandas_path  # Path style access for pandas
from tqdm import tqdm

# %%
import torch
import torchvision
import fasttext

from transformers import BertModel, BertTokenizer

# %%
data_dir = Path.cwd().parent / "data"

img_tar_path = data_dir / "img.tar.gz"
train_path = data_dir / "train1.json"
dev_path = data_dir / "dev1.json"
test_path = data_dir / "test1.json"

# %%
if not (data_dir / "img").exists():
    with tarfile.open(img_tar_path) as tf:
        tf.extractall(data_dir)

# %%
train_samples_frame = pd.read_json(train_path, lines=True)
train_samples_frame.head()
# Out:
#       id            img  label  \
# 0  42953  img/42953.png      0
# 1  23058  img/23058.png      0
# 2  13894  img/13894.png      0
# 3  37408  img/37408.png      0
# 4  82403  img/82403.png      0
#
#                                                 text
# 0   its their character not their color that matters
# 1  don't be afraid to love again everyone is not ...
# 2                           putting bows on your pet
# 3  i love everything and everybody! except for sq...
# 4  everybody loves chocolate chip cookies, even h...

# %%
train_samples_frame.label.value_counts()
# Out:
# 0    4811
# 1    2501
# Name: label, dtype: int64

# %%
train_samples_frame.text.map(
    lambda text: len(text.split(" "))
).describe()
# Out:
# count    7312.000000
# mean       11.730717
# std         6.844690
# min         1.000000
# 25%         7.000000
# 50%        10.000000
# 75%        15.000000
# max        70.000000
# Name: text, dtype: float64

# %%
from PIL import Image


images = [
    Image.open(
        data_dir / train_samples_frame.loc[i, "img"]
    ).convert("RGB")
    for i in range(5)
]

for image in images:
    print(image.size)
# Out:
# (265, 400)
# (800, 533)
# (558, 800)
# (693, 800)
# (550, 416)

# %%
# define a callable image_transform with Compose
image_transform = torchvision.transforms.Compose(
    [
        torchvision.transforms.Resize(size=(224, 224)),
        torchvision.transforms.ToTensor()
    ]
)

# convert the images and prepare for visualization.
tensor_img = torch.stack(
    [image_transform(image) for image in images]
)
grid = torchvision.utils.make_grid(tensor_img)

# plot
plt.rcParams["figure.figsize"] = (20, 5)
plt.axis('off')
_ = plt.imshow(grid.permute(1, 2, 0))

# %%
class HatefulMemesDataset(torch.utils.data.Dataset):
    """Uses jsonl data to preprocess and serve 
    dictionary of multimodal tensors for model input.
    """

    def __init__(
        self,
        data_path,
        img_dir,
        image_transform,
        bert,
        text_transform,
        balance=False,
        dev_limit=None,
        random_state=0,
    ):

        self.samples_frame = pd.read_json(
            data_path, lines=True
        )
        self.dev_limit = dev_limit
        if balance:
            neg = self.samples_frame[
                self.samples_frame.label.eq(0)
            ]
            pos = self.samples_frame[
                self.samples_frame.label.eq(1)
            ]
            self.samples_frame = pd.concat(
                [
                    neg.sample(
                        pos.shape[0], 
                        random_state=random_state
                    ), 
                    pos
                ]
            )
        if self.dev_limit:
            if self.samples_frame.shape[0] > self.dev_limit:
                self.samples_frame = self.samples_frame.sample(
                    dev_limit, random_state=random_state
                )
        self.samples_frame = self.samples_frame.reset_index(
            drop=True
        )
        self.samples_frame.img = self.samples_frame.apply(
            lambda row: (img_dir / row.img), axis=1
        )

        # https://github.com/drivendataorg/pandas-path
        # if not self.samples_frame.img.path.exists().all():
        #     raise FileNotFoundError
        # if not self.samples_frame.img.path.is_file().all():
        #     raise TypeError
            
        self.image_transform = image_transform
        self.text_transform = text_transform
        self.bert = bert
        self.fc = torch.nn.Linear(
            in_features=1024, 
            out_features=300
        )

    def __len__(self):
        """This method is called when you do len(instance) 
        for an instance of this class.
        """
        return len(self.samples_frame)

    def __getitem__(self, idx):
        """This method is called when you do instance[key] 
        for an instance of this class.
        """
        if torch.is_tensor(idx):
            idx = idx.tolist()

        img_id = self.samples_frame.loc[idx, "id"]

        image = Image.open(
            self.samples_frame.loc[idx, "img"]
        ).convert("RGB")
        image = self.image_transform(image)

        # text = torch.Tensor(
        #     self.text_transform.get_sentence_vector(
        #         self.samples_frame.loc[idx, "text"]
        #     )
        # ).squeeze()

        text = self.text_transform(self.samples_frame.loc[idx, "text"], return_tensors="pt")
        device = "cuda:0"
        model = self.bert.to(device)
        text = text.to(device)
        text = model(**text).pooler_output
        fc = self.fc.to(device)
        text = fc(text).squeeze()


        if "label" in self.samples_frame.columns:
            label = torch.Tensor(
                [self.samples_frame.loc[idx, "label"]]
            ).long().squeeze()
            sample = {
                "id": img_id, 
                "image": image, 
                "text": text, 
                "label": label
            }
        else:
            sample = {
                "id": img_id, 
                "image": image, 
                "text": text
            }

        return sample

# %%
class LanguageAndVisionConcat(torch.nn.Module):
    def __init__(
        self,
        num_classes,
        loss_fn,
        language_module,
        vision_module,
        language_feature_dim,
        vision_feature_dim,
        fusion_output_size,
        dropout_p,
        
    ):
        super(LanguageAndVisionConcat, self).__init__()
        self.language_module = language_module
        self.vision_module = vision_module
        self.fusion = torch.nn.Linear(
            in_features=(language_feature_dim + vision_feature_dim), 
            out_features=fusion_output_size
        )
        self.fc = torch.nn.Linear(
            in_features=fusion_output_size, 
            out_features=num_classes
        )
        self.loss_fn = loss_fn
        self.dropout = torch.nn.Dropout(dropout_p)
        
    def forward(self, text, image, label=None):
        text_features = torch.nn.functional.relu(
            self.language_module(text)
        )
        image_features = torch.nn.functional.relu(
            self.vision_module(image)
        )
        combined = torch.cat(
            [text_features, image_features], dim=1
        )
        fused = self.dropout(
            torch.nn.functional.relu(
            self.fusion(combined)
            )
        )
        logits = self.fc(fused)
        pred = torch.nn.functional.softmax(logits)
        loss = (
            self.loss_fn(pred, label) 
            if label is not None else label
        )
        return (pred, loss)

# %%
import pytorch_lightning as pl
import torchmetrics

# for the purposes of this post, we'll filter
# much of the lovely logging info from our LightningModule
warnings.filterwarnings("ignore")
logging.getLogger().setLevel(logging.WARNING)


class HatefulMemesModel(pl.LightningModule):
    def __init__(self, hparams):
        for data_key in ["train_path", "dev_path", "img_dir",]:
            # ok, there's one for-loop but it doesn't count
            if data_key not in hparams.keys():
                raise KeyError(
                    f"{data_key} is a required hparam in this model"
                )
        
        super(HatefulMemesModel, self).__init__()
        self.hparams = hparams
        
        # assign some hparams that get used in multiple places
        self.embedding_dim = self.hparams.get("embedding_dim", 300)
        self.language_feature_dim = self.hparams.get(
            "language_feature_dim", 300
        )
        self.vision_feature_dim = self.hparams.get(
            # balance language and vision features by default
            "vision_feature_dim", self.language_feature_dim
        )
        self.output_path = Path(
            self.hparams.get("output_path", "model-outputs")
        )
        self.output_path.mkdir(exist_ok=True)
        
        # instantiate transforms, datasets
        self.text_transform = self._build_text_transform()
        self.bert = self._build_bert()
        self.image_transform = self._build_image_transform()
        self.train_dataset = self._build_dataset("train_path")
        self.dev_dataset = self._build_dataset("dev_path")
        
        # set up model and training
        self.model = self._build_model()
        self.trainer_params = self._get_trainer_params()
    
    ## Required LightningModule Methods (when validating) ##
    
    def forward(self, text, image, label=None):
        return self.model(text, image, label)

    def training_step(self, batch, batch_nb):
        preds, loss = self.forward(
            text=batch["text"], 
            image=batch["image"], 
            label=batch["label"]
        )

        return {"loss": loss}

    def validation_step(self, batch, batch_nb):
        preds, loss = self.eval().forward(
            text=batch["text"], 
            image=batch["image"], 
            label=batch["label"]
        )
        
        return {"batch_val_loss": loss}

    def validation_epoch_end(self, outputs):
        avg_loss = torch.stack(
            tuple(
                output["batch_val_loss"] 
                for output in outputs
            )
        ).mean()
        
        return {
            "val_loss": avg_loss,
            "progress_bar":{"avg_val_loss": avg_loss}
        }

    def configure_optimizers(self):
        optimizers = [
            torch.optim.AdamW(
                self.model.parameters(), 
                lr=self.hparams.get("lr", 0.001)
            )
        ]
        schedulers = [
            torch.optim.lr_scheduler.ReduceLROnPlateau(
                optimizers[0]
            )
        ]
        return optimizers, schedulers
    
    def train_dataloader(self):
        return torch.utils.data.DataLoader(
            self.train_dataset, 
            shuffle=True, 
            batch_size=self.hparams.get("batch_size", 4), 
            num_workers=self.hparams.get("num_workers", 16)
        )

    def val_dataloader(self):
        return torch.utils.data.DataLoader(
            self.dev_dataset, 
            shuffle=False, 
            batch_size=self.hparams.get("batch_size", 4), 
            num_workers=self.hparams.get("num_workers", 16)
        )
    
    ## Convenience Methods ##
    
    def fit(self):
        self._set_seed(self.hparams.get("random_state", 42))
        self.trainer = pl.Trainer(**self.trainer_params)
        self.trainer.fit(self)
        
    def _set_seed(self, seed):
        random.seed(seed)
        np.random.seed(seed)
        torch.manual_seed(seed)
        if torch.cuda.is_available():
            torch.cuda.manual_seed_all(seed)

    def _build_text_transform(self):
        with tempfile.NamedTemporaryFile(mode='w', delete=False, encoding='utf-8') as ft_training_data:
            ft_path = Path(ft_training_data.name)
            training_data = [
                json.loads(line)["text"] + "/n" 
                for line in open(
                    self.hparams.get("train_path")
                ).read().splitlines()
            ]
            for line in training_data:
                ft_training_data.write(line + "\n")
            # language_transform = fasttext.train_unsupervised(
            #     str(ft_path),
            #     model=self.hparams.get("fasttext_model", "cbow"),
            #     dim=self.embedding_dim
            # )
            language_transform = BertTokenizer.from_pretrained("bert-large-cased")
        return language_transform
    
    def _build_bert(self):
      bert_model = BertModel.from_pretrained('bert-large-cased')
      return bert_model

    def _build_image_transform(self):
        image_dim = self.hparams.get("image_dim", 224)
        image_transform = torchvision.transforms.Compose(
            [
                torchvision.transforms.Resize(
                    size=(image_dim, image_dim)
                ),        
                torchvision.transforms.ToTensor(),
                # all torchvision models expect the same
                # normalization mean and std
                # https://pytorch.org/docs/stable/torchvision/models.html
                torchvision.transforms.Normalize(
                    mean=(0.485, 0.456, 0.406), 
                    std=(0.229, 0.224, 0.225)
                ),
            ]
        )
        return image_transform

    def _build_dataset(self, dataset_key):
        return HatefulMemesDataset(
            data_path=self.hparams.get(dataset_key, dataset_key),
            img_dir=self.hparams.get("img_dir"),
            image_transform=self.image_transform,
            bert = self.bert,
            text_transform=self.text_transform,
            # limit training samples only
            dev_limit=(
                self.hparams.get("dev_limit", None) 
                if "train" in str(dataset_key) else None
            ),
            balance=True if "train" in str(dataset_key) else False,
        )
    
    def _build_model(self):
        # we're going to pass the outputs of our text
        # transform through an additional trainable layer
        # rather than fine-tuning the transform
        language_module = torch.nn.Linear(
                in_features=self.embedding_dim,
                out_features=self.language_feature_dim
        )

        # language_module = BertModel.from_pretrained("bert-base-cased")
        
        # easiest way to get features rather than
        # classification is to overwrite last layer
        # with an identity transformation, we'll reduce
        # dimension using a Linear layer, resnet is 2048 out
        vision_module = torchvision.models.resnet152(
            pretrained=True
        )
        vision_module.fc = torch.nn.Linear(
                in_features=2048,
                out_features=self.vision_feature_dim
        )

        return LanguageAndVisionConcat(
            num_classes=self.hparams.get("num_classes", 2),
            loss_fn=torch.nn.CrossEntropyLoss(),
            language_module=language_module,
            vision_module=vision_module,
            language_feature_dim=self.language_feature_dim,
            vision_feature_dim=self.vision_feature_dim,
            fusion_output_size=self.hparams.get(
                "fusion_output_size", 512
            ),
            dropout_p=self.hparams.get("dropout_p", 0.1),
        )

    def _get_trainer_params(self):
        checkpoint_callback = pl.callbacks.ModelCheckpoint(
            filepath=self.output_path,
            monitor=self.hparams.get(
                "checkpoint_monitor", "avg_val_loss"
            ),
            mode=self.hparams.get(
                "checkpoint_monitor_mode", "min"
            ),
            verbose=self.hparams.get("verbose", True)
        )

        early_stop_callback = pl.callbacks.EarlyStopping(
            monitor=self.hparams.get(
                "early_stop_monitor", "avg_val_loss"
            ),
            min_delta=self.hparams.get(
                "early_stop_min_delta", 0.001
            ),
            patience=self.hparams.get(
                "early_stop_patience", 3
            ),
            verbose=self.hparams.get("verbose", True),
        )

        trainer_params = {
            "checkpoint_callback": checkpoint_callback,
            "early_stop_callback": early_stop_callback,
            "default_save_path": self.output_path,
            "accumulate_grad_batches": self.hparams.get(
                "accumulate_grad_batches", 1
            ),
            "gpus": self.hparams.get("n_gpu", 1),
            "max_epochs": self.hparams.get("max_epochs", 100),
            "gradient_clip_val": self.hparams.get(
                "gradient_clip_value", 1
            ),
        }
        return trainer_params
            
    @torch.no_grad()
    def make_submission_frame(self, test_path):
        test_dataset = self._build_dataset(test_path)
        submission_frame = pd.DataFrame(
            index=test_dataset.samples_frame.id,
            columns=["proba", "label"]
        )
        test_dataloader = torch.utils.data.DataLoader(
            test_dataset, 
            shuffle=False, 
            batch_size=self.hparams.get("batch_size", 4), 
            num_workers=self.hparams.get("num_workers", 16))
        for batch in tqdm(test_dataloader, total=len(test_dataloader)):
            preds, _ = self.model.eval().to("cpu")(
                batch["text"], batch["image"]
            )
            submission_frame.loc[batch["id"], "proba"] = preds[:, 1]
            submission_frame.loc[batch["id"], "label"] = preds.argmax(dim=1)
        submission_frame.proba = submission_frame.proba.astype(float)
        submission_frame.label = submission_frame.label.astype(int)
        return submission_frame

# %%
hparams = {
    
    # Required hparams
    "train_path": train_path,
    "dev_path": dev_path,
    "img_dir": data_dir,
    
    # Optional hparams
    "embedding_dim": 300,
    "language_feature_dim": 300,
    "vision_feature_dim": 300,
    "fusion_output_size": 256,
    "output_path": "model-outputs_02",
    "dev_limit": None,
    "lr": 0.00005,
    "max_epochs": 10,
    "n_gpu": 1,
    "batch_size": 4,
    "num_workers": 0,
    # allows us to "simulate" having larger batches 
    "accumulate_grad_batches": 16,
    "early_stop_patience": 3,
}

hateful_memes_model = HatefulMemesModel(hparams=hparams)
hateful_memes_model.fit()
# Out:
# EarlyStopping mode auto is unknown, fallback to auto mode.
# EarlyStopping mode set to min for monitoring avg_val_loss.
# GPU available: True, used: True
# No environment variable for node rank defined. Set as 0.
# CUDA_VISIBLE_DEVICES: [0]
#
#     | Name                                             | Type                    | Params
# -----------------------------------------------------------------------------------------
# 0   | bert                                             | BertModel               | 333 M
# 1   | bert.embeddings                                  | BertEmbeddings          | 30 M
# 2   | bert.embeddings.word_embeddings                  | Embedding               | 29 M
# 3   | bert.embeddings.position_embeddings              | Embedding               | 524 K
# 4   | bert.embeddings.token_type_embeddings            | Embedding               | 2 K
# 5   | bert.embeddings.LayerNorm                        | LayerNorm               | 2 K
# 6   | bert.embeddings.dropout                          | Dropout                 | 0
# 7   | bert.encoder                                     | BertEncoder             | 302 M
# 8   | bert.encoder.layer                               | ModuleList              | 302 M
# 9   | bert.encoder.layer.0                             | BertLayer               | 12 M
# 10  | bert.encoder.layer.0.attention                   | BertAttention           | 4 M
# 11  | bert.encoder.layer.0.attention.self              | BertSelfAttention       | 3 M
# 12  | bert.encoder.layer.0.attention.self.query        | Linear                  | 1 M
# 13  | bert.encoder.layer.0.attention.self.key          | Linear                  | 1 M
# 14  | bert.encoder.layer.0.attention.self.value        | Linear                  | 1 M
# 15  | bert.encoder.layer.0.attention.self.dropout      | Dropout                 | 0
# 16  | bert.encoder.layer.0.attention.output            | BertSelfOutput          | 1 M
# 17  | bert.encoder.layer.0.attention.output.dense      | Linear                  | 1 M
# 18  | bert.encoder.layer.0.attention.output.LayerNorm  | LayerNorm               | 2 K
# 19  | bert.encoder.layer.0.attention.output.dropout    | Dropout                 | 0
# 20  | bert.encoder.layer.0.intermediate                | BertIntermediate        | 4 M
# 21  | bert.encoder.layer.0.intermediate.dense          | Linear                  | 4 M
# 22  | bert.encoder.layer.0.output                      | BertOutput              | 4 M
# 23  | bert.encoder.layer.0.output.dense                | Linear                  | 4 M
# 24  | bert.encoder.layer.0.output.LayerNorm            | LayerNorm               | 2 K
# 25  | bert.encoder.layer.0.output.dropout              | Dropout                 | 0
# 26  | bert.encoder.layer.1                             | BertLayer               | 12 M
# 27  | bert.encoder.layer.1.attention                   | BertAttention           | 4 M
# 28  | bert.encoder.layer.1.attention.self              | BertSelfAttention       | 3 M
# 29  | bert.encoder.layer.1.attention.self.query        | Linear                  | 1 M
# 30  | bert.encoder.layer.1.attention.self.key          | Linear                  | 1 M
# 31  | bert.encoder.layer.1.attention.self.value        | Linear                  | 1 M
# 32  | bert.encoder.layer.1.attention.self.dropout      | Dropout                 | 0
# 33  | bert.encoder.layer.1.attention.output            | BertSelfOutput          | 1 M
# 34  | bert.encoder.layer.1.attention.output.dense      | Linear                  | 1 M
# 35  | bert.encoder.layer.1.attention.output.LayerNorm  | LayerNorm               | 2 K
# 36  | bert.encoder.layer.1.attention.output.dropout    | Dropout                 | 0
# 37  | bert.encoder.layer.1.intermediate                | BertIntermediate        | 4 M
# 38  | bert.encoder.layer.1.intermediate.dense          | Linear                  | 4 M
# 39  | bert.encoder.layer.1.output                      | BertOutput              | 4 M
# 40  | bert.encoder.layer.1.output.dense                | Linear                  | 4 M
# 41  | bert.encoder.layer.1.output.LayerNorm            | LayerNorm               | 2 K
# 42  | bert.encoder.layer.1.output.dropout              | Dropout                 | 0
# 43  | bert.encoder.layer.2                             | BertLayer               | 12 M
# 44  | bert.encoder.layer.2.attention                   | BertAttention           | 4 M
# 45  | bert.encoder.layer.2.attention.self              | BertSelfAttention       | 3 M
# 46  | bert.encoder.layer.2.attention.self.query        | Linear                  | 1 M
# 47  | bert.encoder.layer.2.attention.self.key          | Linear                  | 1 M
# 48  | bert.encoder.layer.2.attention.self.value        | Linear                  | 1 M
# 49  | bert.encoder.layer.2.attention.self.dropout      | Dropout                 | 0
# 50  | bert.encoder.layer.2.attention.output            | BertSelfOutput          | 1 M
# 51  | bert.encoder.layer.2.attention.output.dense      | Linear                  | 1 M
# 52  | bert.encoder.layer.2.attention.output.LayerNorm  | LayerNorm               | 2 K
# 53  | bert.encoder.layer.2.attention.output.dropout    | Dropout                 | 0
# 54  | bert.encoder.layer.2.intermediate                | BertIntermediate        | 4 M
# 55  | bert.encoder.layer.2.intermediate.dense          | Linear                  | 4 M
# 56  | bert.encoder.layer.2.output                      | BertOutput              | 4 M
# 57  | bert.encoder.layer.2.output.dense                | Linear                  | 4 M
# 58  | bert.encoder.layer.2.output.LayerNorm            | LayerNorm               | 2 K
# 59  | bert.encoder.layer.2.output.dropout              | Dropout                 | 0
# 60  | bert.encoder.layer.3                             | BertLayer               | 12 M
# 61  | bert.encoder.layer.3.attention                   | BertAttention           | 4 M
# 62  | bert.encoder.layer.3.attention.self              | BertSelfAttention       | 3 M
# 63  | bert.encoder.layer.3.attention.self.query        | Linear                  | 1 M
# 64  | bert.encoder.layer.3.attention.self.key          | Linear                  | 1 M
# 65  | bert.encoder.layer.3.attention.self.value        | Linear                  | 1 M
# 66  | bert.encoder.layer.3.attention.self.dropout      | Dropout                 | 0
# 67  | bert.encoder.layer.3.attention.output            | BertSelfOutput          | 1 M
# 68  | bert.encoder.layer.3.attention.output.dense      | Linear                  | 1 M
# 69  | bert.encoder.layer.3.attention.output.LayerNorm  | LayerNorm               | 2 K
# 70  | bert.encoder.layer.3.attention.output.dropout    | Dropout                 | 0
# 71  | bert.encoder.layer.3.intermediate                | BertIntermediate        | 4 M
# 72  | bert.encoder.layer.3.intermediate.dense          | Linear                  | 4 M
# 73  | bert.encoder.layer.3.output                      | BertOutput              | 4 M
# 74  | bert.encoder.layer.3.output.dense                | Linear                  | 4 M
# 75  | bert.encoder.layer.3.output.LayerNorm            | LayerNorm               | 2 K
# 76  | bert.encoder.layer.3.output.dropout              | Dropout                 | 0
# 77  | bert.encoder.layer.4                             | BertLayer               | 12 M
# 78  | bert.encoder.layer.4.attention                   | BertAttention           | 4 M
# 79  | bert.encoder.layer.4.attention.self              | BertSelfAttention       | 3 M
# 80  | bert.encoder.layer.4.attention.self.query        | Linear                  | 1 M
# 81  | bert.encoder.layer.4.attention.self.key          | Linear                  | 1 M
# 82  | bert.encoder.layer.4.attention.self.value        | Linear                  | 1 M
# 83  | bert.encoder.layer.4.attention.self.dropout      | Dropout                 | 0
# 84  | bert.encoder.layer.4.attention.output            | BertSelfOutput          | 1 M
# 85  | bert.encoder.layer.4.attention.output.dense      | Linear                  | 1 M
# 86  | bert.encoder.layer.4.attention.output.LayerNorm  | LayerNorm               | 2 K
# 87  | bert.encoder.layer.4.attention.output.dropout    | Dropout                 | 0
# 88  | bert.encoder.layer.4.intermediate                | BertIntermediate        | 4 M
# 89  | bert.encoder.layer.4.intermediate.dense          | Linear                  | 4 M
# 90  | bert.encoder.layer.4.output                      | BertOutput              | 4 M
# 91  | bert.encoder.layer.4.output.dense                | Linear                  | 4 M
# 92  | bert.encoder.layer.4.output.LayerNorm            | LayerNorm               | 2 K
# 93  | bert.encoder.layer.4.output.dropout              | Dropout                 | 0
# 94  | bert.encoder.layer.5                             | BertLayer               | 12 M
# 95  | bert.encoder.layer.5.attention                   | BertAttention           | 4 M
# 96  | bert.encoder.layer.5.attention.self              | BertSelfAttention       | 3 M
# 97  | bert.encoder.layer.5.attention.self.query        | Linear                  | 1 M
# 98  | bert.encoder.layer.5.attention.self.key          | Linear                  | 1 M
# 99  | bert.encoder.layer.5.attention.self.value        | Linear                  | 1 M
# 100 | bert.encoder.layer.5.attention.self.dropout      | Dropout                 | 0
# 101 | bert.encoder.layer.5.attention.output            | BertSelfOutput          | 1 M
# 102 | bert.encoder.layer.5.attention.output.dense      | Linear                  | 1 M
# 103 | bert.encoder.layer.5.attention.output.LayerNorm  | LayerNorm               | 2 K
# 104 | bert.encoder.layer.5.attention.output.dropout    | Dropout                 | 0
# 105 | bert.encoder.layer.5.intermediate                | BertIntermediate        | 4 M
# 106 | bert.encoder.layer.5.intermediate.dense          | Linear                  | 4 M
# 107 | bert.encoder.layer.5.output                      | BertOutput              | 4 M
# 108 | bert.encoder.layer.5.output.dense                | Linear                  | 4 M
# 109 | bert.encoder.layer.5.output.LayerNorm            | LayerNorm               | 2 K
# 110 | bert.encoder.layer.5.output.dropout              | Dropout                 | 0
# 111 | bert.encoder.layer.6                             | BertLayer               | 12 M
# 112 | bert.encoder.layer.6.attention                   | BertAttention           | 4 M
# 113 | bert.encoder.layer.6.attention.self              | BertSelfAttention       | 3 M
# 114 | bert.encoder.layer.6.attention.self.query        | Linear                  | 1 M
# 115 | bert.encoder.layer.6.attention.self.key          | Linear                  | 1 M
# 116 | bert.encoder.layer.6.attention.self.value        | Linear                  | 1 M
# 117 | bert.encoder.layer.6.attention.self.dropout      | Dropout                 | 0
# 118 | bert.encoder.layer.6.attention.output            | BertSelfOutput          | 1 M
# 119 | bert.encoder.layer.6.attention.output.dense      | Linear                  | 1 M
# 120 | bert.encoder.layer.6.attention.output.LayerNorm  | LayerNorm               | 2 K
# 121 | bert.encoder.layer.6.attention.output.dropout    | Dropout                 | 0
# 122 | bert.encoder.layer.6.intermediate                | BertIntermediate        | 4 M
# 123 | bert.encoder.layer.6.intermediate.dense          | Linear                  | 4 M
# 124 | bert.encoder.layer.6.output                      | BertOutput              | 4 M
# 125 | bert.encoder.layer.6.output.dense                | Linear                  | 4 M
# 126 | bert.encoder.layer.6.output.LayerNorm            | LayerNorm               | 2 K
# 127 | bert.encoder.layer.6.output.dropout              | Dropout                 | 0
# 128 | bert.encoder.layer.7                             | BertLayer               | 12 M
# 129 | bert.encoder.layer.7.attention                   | BertAttention           | 4 M
# 130 | bert.encoder.layer.7.attention.self              | BertSelfAttention       | 3 M
# 131 | bert.encoder.layer.7.attention.self.query        | Linear                  | 1 M
# 132 | bert.encoder.layer.7.attention.self.key          | Linear                  | 1 M
# 133 | bert.encoder.layer.7.attention.self.value        | Linear                  | 1 M
# 134 | bert.encoder.layer.7.attention.self.dropout      | Dropout                 | 0
# 135 | bert.encoder.layer.7.attention.output            | BertSelfOutput          | 1 M
# 136 | bert.encoder.layer.7.attention.output.dense      | Linear                  | 1 M
# 137 | bert.encoder.layer.7.attention.output.LayerNorm  | LayerNorm               | 2 K
# 138 | bert.encoder.layer.7.attention.output.dropout    | Dropout                 | 0
# 139 | bert.encoder.layer.7.intermediate                | BertIntermediate        | 4 M
# 140 | bert.encoder.layer.7.intermediate.dense          | Linear                  | 4 M
# 141 | bert.encoder.layer.7.output                      | BertOutput              | 4 M
# 142 | bert.encoder.layer.7.output.dense                | Linear                  | 4 M
# 143 | bert.encoder.layer.7.output.LayerNorm            | LayerNorm               | 2 K
# 144 | bert.encoder.layer.7.output.dropout              | Dropout                 | 0
# 145 | bert.encoder.layer.8                             | BertLayer               | 12 M
# 146 | bert.encoder.layer.8.attention                   | BertAttention           | 4 M
# 147 | bert.encoder.layer.8.attention.self              | BertSelfAttention       | 3 M
# 148 | bert.encoder.layer.8.attention.self.query        | Linear                  | 1 M
# 149 | bert.encoder.layer.8.attention.self.key          | Linear                  | 1 M
# 150 | bert.encoder.layer.8.attention.self.value        | Linear                  | 1 M
# 151 | bert.encoder.layer.8.attention.self.dropout      | Dropout                 | 0
# 152 | bert.encoder.layer.8.attention.output            | BertSelfOutput          | 1 M
# 153 | bert.encoder.layer.8.attention.output.dense      | Linear                  | 1 M
# 154 | bert.encoder.layer.8.attention.output.LayerNorm  | LayerNorm               | 2 K
# 155 | bert.encoder.layer.8.attention.output.dropout    | Dropout                 | 0
# 156 | bert.encoder.layer.8.intermediate                | BertIntermediate        | 4 M
# 157 | bert.encoder.layer.8.intermediate.dense          | Linear                  | 4 M
# 158 | bert.encoder.layer.8.output                      | BertOutput              | 4 M
# 159 | bert.encoder.layer.8.output.dense                | Linear                  | 4 M
# 160 | bert.encoder.layer.8.output.LayerNorm            | LayerNorm               | 2 K
# 161 | bert.encoder.layer.8.output.dropout              | Dropout                 | 0
# 162 | bert.encoder.layer.9                             | BertLayer               | 12 M
# 163 | bert.encoder.layer.9.attention                   | BertAttention           | 4 M
# 164 | bert.encoder.layer.9.attention.self              | BertSelfAttention       | 3 M
# 165 | bert.encoder.layer.9.attention.self.query        | Linear                  | 1 M
# 166 | bert.encoder.layer.9.attention.self.key          | Linear                  | 1 M
# 167 | bert.encoder.layer.9.attention.self.value        | Linear                  | 1 M
# 168 | bert.encoder.layer.9.attention.self.dropout      | Dropout                 | 0
# 169 | bert.encoder.layer.9.attention.output            | BertSelfOutput          | 1 M
# 170 | bert.encoder.layer.9.attention.output.dense      | Linear                  | 1 M
# 171 | bert.encoder.layer.9.attention.output.LayerNorm  | LayerNorm               | 2 K
# 172 | bert.encoder.layer.9.attention.output.dropout    | Dropout                 | 0
# 173 | bert.encoder.layer.9.intermediate                | BertIntermediate        | 4 M
# 174 | bert.encoder.layer.9.intermediate.dense          | Linear                  | 4 M
# 175 | bert.encoder.layer.9.output                      | BertOutput              | 4 M
# 176 | bert.encoder.layer.9.output.dense                | Linear                  | 4 M
# 177 | bert.encoder.layer.9.output.LayerNorm            | LayerNorm               | 2 K
# 178 | bert.encoder.layer.9.output.dropout              | Dropout                 | 0
# 179 | bert.encoder.layer.10                            | BertLayer               | 12 M
# 180 | bert.encoder.layer.10.attention                  | BertAttention           | 4 M
# 181 | bert.encoder.layer.10.attention.self             | BertSelfAttention       | 3 M
# 182 | bert.encoder.layer.10.attention.self.query       | Linear                  | 1 M
# 183 | bert.encoder.layer.10.attention.self.key         | Linear                  | 1 M
# 184 | bert.encoder.layer.10.attention.self.value       | Linear                  | 1 M
# 185 | bert.encoder.layer.10.attention.self.dropout     | Dropout                 | 0
# 186 | bert.encoder.layer.10.attention.output           | BertSelfOutput          | 1 M
# 187 | bert.encoder.layer.10.attention.output.dense     | Linear                  | 1 M
# 188 | bert.encoder.layer.10.attention.output.LayerNorm | LayerNorm               | 2 K
# 189 | bert.encoder.layer.10.attention.output.dropout   | Dropout                 | 0
# 190 | bert.encoder.layer.10.intermediate               | BertIntermediate        | 4 M
# 191 | bert.encoder.layer.10.intermediate.dense         | Linear                  | 4 M
# 192 | bert.encoder.layer.10.output                     | BertOutput              | 4 M
# 193 | bert.encoder.layer.10.output.dense               | Linear                  | 4 M
# 194 | bert.encoder.layer.10.output.LayerNorm           | LayerNorm               | 2 K
# 195 | bert.encoder.layer.10.output.dropout             | Dropout                 | 0
# 196 | bert.encoder.layer.11                            | BertLayer               | 12 M
# 197 | bert.encoder.layer.11.attention                  | BertAttention           | 4 M
# 198 | bert.encoder.layer.11.attention.self             | BertSelfAttention       | 3 M
# 199 | bert.encoder.layer.11.attention.self.query       | Linear                  | 1 M
# 200 | bert.encoder.layer.11.attention.self.key         | Linear                  | 1 M
# 201 | bert.encoder.layer.11.attention.self.value       | Linear                  | 1 M
# 202 | bert.encoder.layer.11.attention.self.dropout     | Dropout                 | 0
# 203 | bert.encoder.layer.11.attention.output           | BertSelfOutput          | 1 M
# 204 | bert.encoder.layer.11.attention.output.dense     | Linear                  | 1 M
# 205 | bert.encoder.layer.11.attention.output.LayerNorm | LayerNorm               | 2 K
# 206 | bert.encoder.layer.11.attention.output.dropout   | Dropout                 | 0
# 207 | bert.encoder.layer.11.intermediate               | BertIntermediate        | 4 M
# 208 | bert.encoder.layer.11.intermediate.dense         | Linear                  | 4 M
# 209 | bert.encoder.layer.11.output                     | BertOutput              | 4 M
# 210 | bert.encoder.layer.11.output.dense               | Linear                  | 4 M
# 211 | bert.encoder.layer.11.output.LayerNorm           | LayerNorm               | 2 K
# 212 | bert.encoder.layer.11.output.dropout             | Dropout                 | 0
# 213 | bert.encoder.layer.12                            | BertLayer               | 12 M
# 214 | bert.encoder.layer.12.attention                  | BertAttention           | 4 M
# 215 | bert.encoder.layer.12.attention.self             | BertSelfAttention       | 3 M
# 216 | bert.encoder.layer.12.attention.self.query       | Linear                  | 1 M
# 217 | bert.encoder.layer.12.attention.self.key         | Linear                  | 1 M
# 218 | bert.encoder.layer.12.attention.self.value       | Linear                  | 1 M
# 219 | bert.encoder.layer.12.attention.self.dropout     | Dropout                 | 0
# 220 | bert.encoder.layer.12.attention.output           | BertSelfOutput          | 1 M
# 221 | bert.encoder.layer.12.attention.output.dense     | Linear                  | 1 M
# 222 | bert.encoder.layer.12.attention.output.LayerNorm | LayerNorm               | 2 K
# 223 | bert.encoder.layer.12.attention.output.dropout   | Dropout                 | 0
# 224 | bert.encoder.layer.12.intermediate               | BertIntermediate        | 4 M
# 225 | bert.encoder.layer.12.intermediate.dense         | Linear                  | 4 M
# 226 | bert.encoder.layer.12.output                     | BertOutput              | 4 M
# 227 | bert.encoder.layer.12.output.dense               | Linear                  | 4 M
# 228 | bert.encoder.layer.12.output.LayerNorm           | LayerNorm               | 2 K
# 229 | bert.encoder.layer.12.output.dropout             | Dropout                 | 0
# 230 | bert.encoder.layer.13                            | BertLayer               | 12 M
# 231 | bert.encoder.layer.13.attention                  | BertAttention           | 4 M
# 232 | bert.encoder.layer.13.attention.self             | BertSelfAttention       | 3 M
# 233 | bert.encoder.layer.13.attention.self.query       | Linear                  | 1 M
# 234 | bert.encoder.layer.13.attention.self.key         | Linear                  | 1 M
# 235 | bert.encoder.layer.13.attention.self.value       | Linear                  | 1 M
# 236 | bert.encoder.layer.13.attention.self.dropout     | Dropout                 | 0
# 237 | bert.encoder.layer.13.attention.output           | BertSelfOutput          | 1 M
# 238 | bert.encoder.layer.13.attention.output.dense     | Linear                  | 1 M
# 239 | bert.encoder.layer.13.attention.output.LayerNorm | LayerNorm               | 2 K
# 240 | bert.encoder.layer.13.attention.output.dropout   | Dropout                 | 0
# 241 | bert.encoder.layer.13.intermediate               | BertIntermediate        | 4 M
# 242 | bert.encoder.layer.13.intermediate.dense         | Linear                  | 4 M
# 243 | bert.encoder.layer.13.output                     | BertOutput              | 4 M
# 244 | bert.encoder.layer.13.output.dense               | Linear                  | 4 M
# 245 | bert.encoder.layer.13.output.LayerNorm           | LayerNorm               | 2 K
# 246 | bert.encoder.layer.13.output.dropout             | Dropout                 | 0
# 247 | bert.encoder.layer.14                            | BertLayer               | 12 M
# 248 | bert.encoder.layer.14.attention                  | BertAttention           | 4 M
# 249 | bert.encoder.layer.14.attention.self             | BertSelfAttention       | 3 M
# 250 | bert.encoder.layer.14.attention.self.query       | Linear                  | 1 M
# 251 | bert.encoder.layer.14.attention.self.key         | Linear                  | 1 M
# 252 | bert.encoder.layer.14.attention.self.value       | Linear                  | 1 M
# 253 | bert.encoder.layer.14.attention.self.dropout     | Dropout                 | 0
# 254 | bert.encoder.layer.14.attention.output           | BertSelfOutput          | 1 M
# 255 | bert.encoder.layer.14.attention.output.dense     | Linear                  | 1 M
# 256 | bert.encoder.layer.14.attention.output.LayerNorm | LayerNorm               | 2 K
# 257 | bert.encoder.layer.14.attention.output.dropout   | Dropout                 | 0
# 258 | bert.encoder.layer.14.intermediate               | BertIntermediate        | 4 M
# 259 | bert.encoder.layer.14.intermediate.dense         | Linear                  | 4 M
# 260 | bert.encoder.layer.14.output                     | BertOutput              | 4 M
# 261 | bert.encoder.layer.14.output.dense               | Linear                  | 4 M
# 262 | bert.encoder.layer.14.output.LayerNorm           | LayerNorm               | 2 K
# 263 | bert.encoder.layer.14.output.dropout             | Dropout                 | 0
# 264 | bert.encoder.layer.15                            | BertLayer               | 12 M
# 265 | bert.encoder.layer.15.attention                  | BertAttention           | 4 M
# 266 | bert.encoder.layer.15.attention.self             | BertSelfAttention       | 3 M
# 267 | bert.encoder.layer.15.attention.self.query       | Linear                  | 1 M
# 268 | bert.encoder.layer.15.attention.self.key         | Linear                  | 1 M
# 269 | bert.encoder.layer.15.attention.self.value       | Linear                  | 1 M
# 270 | bert.encoder.layer.15.attention.self.dropout     | Dropout                 | 0
# 271 | bert.encoder.layer.15.attention.output           | BertSelfOutput          | 1 M
# 272 | bert.encoder.layer.15.attention.output.dense     | Linear                  | 1 M
# 273 | bert.encoder.layer.15.attention.output.LayerNorm | LayerNorm               | 2 K
# 274 | bert.encoder.layer.15.attention.output.dropout   | Dropout                 | 0
# 275 | bert.encoder.layer.15.intermediate               | BertIntermediate        | 4 M
# 276 | bert.encoder.layer.15.intermediate.dense         | Linear                  | 4 M
# 277 | bert.encoder.layer.15.output                     | BertOutput              | 4 M
# 278 | bert.encoder.layer.15.output.dense               | Linear                  | 4 M
# 279 | bert.encoder.layer.15.output.LayerNorm           | LayerNorm               | 2 K
# 280 | bert.encoder.layer.15.output.dropout             | Dropout                 | 0
# 281 | bert.encoder.layer.16                            | BertLayer               | 12 M
# 282 | bert.encoder.layer.16.attention                  | BertAttention           | 4 M
# 283 | bert.encoder.layer.16.attention.self             | BertSelfAttention       | 3 M
# 284 | bert.encoder.layer.16.attention.self.query       | Linear                  | 1 M
# 285 | bert.encoder.layer.16.attention.self.key         | Linear                  | 1 M
# 286 | bert.encoder.layer.16.attention.self.value       | Linear                  | 1 M
# 287 | bert.encoder.layer.16.attention.self.dropout     | Dropout                 | 0
# 288 | bert.encoder.layer.16.attention.output           | BertSelfOutput          | 1 M
# 289 | bert.encoder.layer.16.attention.output.dense     | Linear                  | 1 M
# 290 | bert.encoder.layer.16.attention.output.LayerNorm | LayerNorm               | 2 K
# 291 | bert.encoder.layer.16.attention.output.dropout   | Dropout                 | 0
# 292 | bert.encoder.layer.16.intermediate               | BertIntermediate        | 4 M
# 293 | bert.encoder.layer.16.intermediate.dense         | Linear                  | 4 M
# 294 | bert.encoder.layer.16.output                     | BertOutput              | 4 M
# 295 | bert.encoder.layer.16.output.dense               | Linear                  | 4 M
# 296 | bert.encoder.layer.16.output.LayerNorm           | LayerNorm               | 2 K
# 297 | bert.encoder.layer.16.output.dropout             | Dropout                 | 0
# 298 | bert.encoder.layer.17                            | BertLayer               | 12 M
# 299 | bert.encoder.layer.17.attention                  | BertAttention           | 4 M
# 300 | bert.encoder.layer.17.attention.self             | BertSelfAttention       | 3 M
# 301 | bert.encoder.layer.17.attention.self.query       | Linear                  | 1 M
# 302 | bert.encoder.layer.17.attention.self.key         | Linear                  | 1 M
# 303 | bert.encoder.layer.17.attention.self.value       | Linear                  | 1 M
# 304 | bert.encoder.layer.17.attention.self.dropout     | Dropout                 | 0
# 305 | bert.encoder.layer.17.attention.output           | BertSelfOutput          | 1 M
# 306 | bert.encoder.layer.17.attention.output.dense     | Linear                  | 1 M
# 307 | bert.encoder.layer.17.attention.output.LayerNorm | LayerNorm               | 2 K
# 308 | bert.encoder.layer.17.attention.output.dropout   | Dropout                 | 0
# 309 | bert.encoder.layer.17.intermediate               | BertIntermediate        | 4 M
# 310 | bert.encoder.layer.17.intermediate.dense         | Linear                  | 4 M
# 311 | bert.encoder.layer.17.output                     | BertOutput              | 4 M
# 312 | bert.encoder.layer.17.output.dense               | Linear                  | 4 M
# 313 | bert.encoder.layer.17.output.LayerNorm           | LayerNorm               | 2 K
# 314 | bert.encoder.layer.17.output.dropout             | Dropout                 | 0
# 315 | bert.encoder.layer.18                            | BertLayer               | 12 M
# 316 | bert.encoder.layer.18.attention                  | BertAttention           | 4 M
# 317 | bert.encoder.layer.18.attention.self             | BertSelfAttention       | 3 M
# 318 | bert.encoder.layer.18.attention.self.query       | Linear                  | 1 M
# 319 | bert.encoder.layer.18.attention.self.key         | Linear                  | 1 M
# 320 | bert.encoder.layer.18.attention.self.value       | Linear                  | 1 M
# 321 | bert.encoder.layer.18.attention.self.dropout     | Dropout                 | 0
# 322 | bert.encoder.layer.18.attention.output           | BertSelfOutput          | 1 M
# 323 | bert.encoder.layer.18.attention.output.dense     | Linear                  | 1 M
# 324 | bert.encoder.layer.18.attention.output.LayerNorm | LayerNorm               | 2 K
# 325 | bert.encoder.layer.18.attention.output.dropout   | Dropout                 | 0
# 326 | bert.encoder.layer.18.intermediate               | BertIntermediate        | 4 M
# 327 | bert.encoder.layer.18.intermediate.dense         | Linear                  | 4 M
# 328 | bert.encoder.layer.18.output                     | BertOutput              | 4 M
# 329 | bert.encoder.layer.18.output.dense               | Linear                  | 4 M
# 330 | bert.encoder.layer.18.output.LayerNorm           | LayerNorm               | 2 K
# 331 | bert.encoder.layer.18.output.dropout             | Dropout                 | 0
# 332 | bert.encoder.layer.19                            | BertLayer               | 12 M
# 333 | bert.encoder.layer.19.attention                  | BertAttention           | 4 M
# 334 | bert.encoder.layer.19.attention.self             | BertSelfAttention       | 3 M
# 335 | bert.encoder.layer.19.attention.self.query       | Linear                  | 1 M
# 336 | bert.encoder.layer.19.attention.self.key         | Linear                  | 1 M
# 337 | bert.encoder.layer.19.attention.self.value       | Linear                  | 1 M
# 338 | bert.encoder.layer.19.attention.self.dropout     | Dropout                 | 0
# 339 | bert.encoder.layer.19.attention.output           | BertSelfOutput          | 1 M
# 340 | bert.encoder.layer.19.attention.output.dense     | Linear                  | 1 M
# 341 | bert.encoder.layer.19.attention.output.LayerNorm | LayerNorm               | 2 K
# 342 | bert.encoder.layer.19.attention.output.dropout   | Dropout                 | 0
# 343 | bert.encoder.layer.19.intermediate               | BertIntermediate        | 4 M
# 344 | bert.encoder.layer.19.intermediate.dense         | Linear                  | 4 M
# 345 | bert.encoder.layer.19.output                     | BertOutput              | 4 M
# 346 | bert.encoder.layer.19.output.dense               | Linear                  | 4 M
# 347 | bert.encoder.layer.19.output.LayerNorm           | LayerNorm               | 2 K
# 348 | bert.encoder.layer.19.output.dropout             | Dropout                 | 0
# 349 | bert.encoder.layer.20                            | BertLayer               | 12 M
# 350 | bert.encoder.layer.20.attention                  | BertAttention           | 4 M
# 351 | bert.encoder.layer.20.attention.self             | BertSelfAttention       | 3 M
# 352 | bert.encoder.layer.20.attention.self.query       | Linear                  | 1 M
# 353 | bert.encoder.layer.20.attention.self.key         | Linear                  | 1 M
# 354 | bert.encoder.layer.20.attention.self.value       | Linear                  | 1 M
# 355 | bert.encoder.layer.20.attention.self.dropout     | Dropout                 | 0
# 356 | bert.encoder.layer.20.attention.output           | BertSelfOutput          | 1 M
# 357 | bert.encoder.layer.20.attention.output.dense     | Linear                  | 1 M
# 358 | bert.encoder.layer.20.attention.output.LayerNorm | LayerNorm               | 2 K
# 359 | bert.encoder.layer.20.attention.output.dropout   | Dropout                 | 0
# 360 | bert.encoder.layer.20.intermediate               | BertIntermediate        | 4 M
# 361 | bert.encoder.layer.20.intermediate.dense         | Linear                  | 4 M
# 362 | bert.encoder.layer.20.output                     | BertOutput              | 4 M
# 363 | bert.encoder.layer.20.output.dense               | Linear                  | 4 M
# 364 | bert.encoder.layer.20.output.LayerNorm           | LayerNorm               | 2 K
# 365 | bert.encoder.layer.20.output.dropout             | Dropout                 | 0
# 366 | bert.encoder.layer.21                            | BertLayer               | 12 M
# 367 | bert.encoder.layer.21.attention                  | BertAttention           | 4 M
# 368 | bert.encoder.layer.21.attention.self             | BertSelfAttention       | 3 M
# 369 | bert.encoder.layer.21.attention.self.query       | Linear                  | 1 M
# 370 | bert.encoder.layer.21.attention.self.key         | Linear                  | 1 M
# 371 | bert.encoder.layer.21.attention.self.value       | Linear                  | 1 M
# 372 | bert.encoder.layer.21.attention.self.dropout     | Dropout                 | 0
# 373 | bert.encoder.layer.21.attention.output           | BertSelfOutput          | 1 M
# 374 | bert.encoder.layer.21.attention.output.dense     | Linear                  | 1 M
# 375 | bert.encoder.layer.21.attention.output.LayerNorm | LayerNorm               | 2 K
# 376 | bert.encoder.layer.21.attention.output.dropout   | Dropout                 | 0
# 377 | bert.encoder.layer.21.intermediate               | BertIntermediate        | 4 M
# 378 | bert.encoder.layer.21.intermediate.dense         | Linear                  | 4 M
# 379 | bert.encoder.layer.21.output                     | BertOutput              | 4 M
# 380 | bert.encoder.layer.21.output.dense               | Linear                  | 4 M
# 381 | bert.encoder.layer.21.output.LayerNorm           | LayerNorm               | 2 K
# 382 | bert.encoder.layer.21.output.dropout             | Dropout                 | 0
# 383 | bert.encoder.layer.22                            | BertLayer               | 12 M
# 384 | bert.encoder.layer.22.attention                  | BertAttention           | 4 M
# 385 | bert.encoder.layer.22.attention.self             | BertSelfAttention       | 3 M
# 386 | bert.encoder.layer.22.attention.self.query       | Linear                  | 1 M
# 387 | bert.encoder.layer.22.attention.self.key         | Linear                  | 1 M
# 388 | bert.encoder.layer.22.attention.self.value       | Linear                  | 1 M
# 389 | bert.encoder.layer.22.attention.self.dropout     | Dropout                 | 0
# 390 | bert.encoder.layer.22.attention.output           | BertSelfOutput          | 1 M
# 391 | bert.encoder.layer.22.attention.output.dense     | Linear                  | 1 M
# 392 | bert.encoder.layer.22.attention.output.LayerNorm | LayerNorm               | 2 K
# 393 | bert.encoder.layer.22.attention.output.dropout   | Dropout                 | 0
# 394 | bert.encoder.layer.22.intermediate               | BertIntermediate        | 4 M
# 395 | bert.encoder.layer.22.intermediate.dense         | Linear                  | 4 M
# 396 | bert.encoder.layer.22.output                     | BertOutput              | 4 M
# 397 | bert.encoder.layer.22.output.dense               | Linear                  | 4 M
# 398 | bert.encoder.layer.22.output.LayerNorm           | LayerNorm               | 2 K
# 399 | bert.encoder.layer.22.output.dropout             | Dropout                 | 0
# 400 | bert.encoder.layer.23                            | BertLayer               | 12 M
# 401 | bert.encoder.layer.23.attention                  | BertAttention           | 4 M
# 402 | bert.encoder.layer.23.attention.self             | BertSelfAttention       | 3 M
# 403 | bert.encoder.layer.23.attention.self.query       | Linear                  | 1 M
# 404 | bert.encoder.layer.23.attention.self.key         | Linear                  | 1 M
# 405 | bert.encoder.layer.23.attention.self.value       | Linear                  | 1 M
# 406 | bert.encoder.layer.23.attention.self.dropout     | Dropout                 | 0
# 407 | bert.encoder.layer.23.attention.output           | BertSelfOutput          | 1 M
# 408 | bert.encoder.layer.23.attention.output.dense     | Linear                  | 1 M
# 409 | bert.encoder.layer.23.attention.output.LayerNorm | LayerNorm               | 2 K
# 410 | bert.encoder.layer.23.attention.output.dropout   | Dropout                 | 0
# 411 | bert.encoder.layer.23.intermediate               | BertIntermediate        | 4 M
# 412 | bert.encoder.layer.23.intermediate.dense         | Linear                  | 4 M
# 413 | bert.encoder.layer.23.output                     | BertOutput              | 4 M
# 414 | bert.encoder.layer.23.output.dense               | Linear                  | 4 M
# 415 | bert.encoder.layer.23.output.LayerNorm           | LayerNorm               | 2 K
# 416 | bert.encoder.layer.23.output.dropout             | Dropout                 | 0
# 417 | bert.pooler                                      | BertPooler              | 1 M
# 418 | bert.pooler.dense                                | Linear                  | 1 M
# 419 | bert.pooler.activation                           | Tanh                    | 0
# 420 | model                                            | LanguageAndVisionConcat | 59 M
# 421 | model.language_module                            | Linear                  | 90 K
# 422 | model.vision_module                              | ResNet                  | 58 M
# 423 | model.vision_module.conv1                        | Conv2d                  | 9 K
# 424 | model.vision_module.bn1                          | BatchNorm2d             | 128
# 425 | model.vision_module.relu                         | ReLU                    | 0
# 426 | model.vision_module.maxpool                      | MaxPool2d               | 0
# 427 | model.vision_module.layer1                       | Sequential              | 215 K
# 428 | model.vision_module.layer1.0                     | Bottleneck              | 75 K
# 429 | model.vision_module.layer1.0.conv1               | Conv2d                  | 4 K
# 430 | model.vision_module.layer1.0.bn1                 | BatchNorm2d             | 128
# 431 | model.vision_module.layer1.0.conv2               | Conv2d                  | 36 K
# 432 | model.vision_module.layer1.0.bn2                 | BatchNorm2d             | 128
# 433 | model.vision_module.layer1.0.conv3               | Conv2d                  | 16 K
# 434 | model.vision_module.layer1.0.bn3                 | BatchNorm2d             | 512
# 435 | model.vision_module.layer1.0.relu                | ReLU                    | 0
# 436 | model.vision_module.layer1.0.downsample          | Sequential              | 16 K
# 437 | model.vision_module.layer1.0.downsample.0        | Conv2d                  | 16 K
# 438 | model.vision_module.layer1.0.downsample.1        | BatchNorm2d             | 512
# 439 | model.vision_module.layer1.1                     | Bottleneck              | 70 K
# 440 | model.vision_module.layer1.1.conv1               | Conv2d                  | 16 K
# 441 | model.vision_module.layer1.1.bn1                 | BatchNorm2d             | 128
# 442 | model.vision_module.layer1.1.conv2               | Conv2d                  | 36 K
# 443 | model.vision_module.layer1.1.bn2                 | BatchNorm2d             | 128
# 444 | model.vision_module.layer1.1.conv3               | Conv2d                  | 16 K
# 445 | model.vision_module.layer1.1.bn3                 | BatchNorm2d             | 512
# 446 | model.vision_module.layer1.1.relu                | ReLU                    | 0
# 447 | model.vision_module.layer1.2                     | Bottleneck              | 70 K
# 448 | model.vision_module.layer1.2.conv1               | Conv2d                  | 16 K
# 449 | model.vision_module.layer1.2.bn1                 | BatchNorm2d             | 128
# 450 | model.vision_module.layer1.2.conv2               | Conv2d                  | 36 K
# 451 | model.vision_module.layer1.2.bn2                 | BatchNorm2d             | 128
# 452 | model.vision_module.layer1.2.conv3               | Conv2d                  | 16 K
# 453 | model.vision_module.layer1.2.bn3                 | BatchNorm2d             | 512
# 454 | model.vision_module.layer1.2.relu                | ReLU                    | 0
# 455 | model.vision_module.layer2                       | Sequential              | 2 M
# 456 | model.vision_module.layer2.0                     | Bottleneck              | 379 K
# 457 | model.vision_module.layer2.0.conv1               | Conv2d                  | 32 K
# 458 | model.vision_module.layer2.0.bn1                 | BatchNorm2d             | 256
# 459 | model.vision_module.layer2.0.conv2               | Conv2d                  | 147 K
# 460 | model.vision_module.layer2.0.bn2                 | BatchNorm2d             | 256
# 461 | model.vision_module.layer2.0.conv3               | Conv2d                  | 65 K
# 462 | model.vision_module.layer2.0.bn3                 | BatchNorm2d             | 1 K
# 463 | model.vision_module.layer2.0.relu                | ReLU                    | 0
# 464 | model.vision_module.layer2.0.downsample          | Sequential              | 132 K
# 465 | model.vision_module.layer2.0.downsample.0        | Conv2d                  | 131 K
# 466 | model.vision_module.layer2.0.downsample.1        | BatchNorm2d             | 1 K
# 467 | model.vision_module.layer2.1                     | Bottleneck              | 280 K
# 468 | model.vision_module.layer2.1.conv1               | Conv2d                  | 65 K
# 469 | model.vision_module.layer2.1.bn1                 | BatchNorm2d             | 256
# 470 | model.vision_module.layer2.1.conv2               | Conv2d                  | 147 K
# 471 | model.vision_module.layer2.1.bn2                 | BatchNorm2d             | 256
# 472 | model.vision_module.layer2.1.conv3               | Conv2d                  | 65 K
# 473 | model.vision_module.layer2.1.bn3                 | BatchNorm2d             | 1 K
# 474 | model.vision_module.layer2.1.relu                | ReLU                    | 0
# 475 | model.vision_module.layer2.2                     | Bottleneck              | 280 K
# 476 | model.vision_module.layer2.2.conv1               | Conv2d                  | 65 K
# 477 | model.vision_module.layer2.2.bn1                 | BatchNorm2d             | 256
# 478 | model.vision_module.layer2.2.conv2               | Conv2d                  | 147 K
# 479 | model.vision_module.layer2.2.bn2                 | BatchNorm2d             | 256
# 480 | model.vision_module.layer2.2.conv3               | Conv2d                  | 65 K
# 481 | model.vision_module.layer2.2.bn3                 | BatchNorm2d             | 1 K
# 482 | model.vision_module.layer2.2.relu                | ReLU                    | 0
# 483 | model.vision_module.layer2.3                     | Bottleneck              | 280 K
# 484 | model.vision_module.layer2.3.conv1               | Conv2d                  | 65 K
# 485 | model.vision_module.layer2.3.bn1                 | BatchNorm2d             | 256
# 486 | model.vision_module.layer2.3.conv2               | Conv2d                  | 147 K
# 487 | model.vision_module.layer2.3.bn2                 | BatchNorm2d             | 256
# 488 | model.vision_module.layer2.3.conv3               | Conv2d                  | 65 K
# 489 | model.vision_module.layer2.3.bn3                 | BatchNorm2d             | 1 K
# 490 | model.vision_module.layer2.3.relu                | ReLU                    | 0
# 491 | model.vision_module.layer2.4                     | Bottleneck              | 280 K
# 492 | model.vision_module.layer2.4.conv1               | Conv2d                  | 65 K
# 493 | model.vision_module.layer2.4.bn1                 | BatchNorm2d             | 256
# 494 | model.vision_module.layer2.4.conv2               | Conv2d                  | 147 K
# 495 | model.vision_module.layer2.4.bn2                 | BatchNorm2d             | 256
# 496 | model.vision_module.layer2.4.conv3               | Conv2d                  | 65 K
# 497 | model.vision_module.layer2.4.bn3                 | BatchNorm2d             | 1 K
# 498 | model.vision_module.layer2.4.relu                | ReLU                    | 0
# 499 | model.vision_module.layer2.5                     | Bottleneck              | 280 K
# 500 | model.vision_module.layer2.5.conv1               | Conv2d                  | 65 K
# 501 | model.vision_module.layer2.5.bn1                 | BatchNorm2d             | 256
# 502 | model.vision_module.layer2.5.conv2               | Conv2d                  | 147 K
# 503 | model.vision_module.layer2.5.bn2                 | BatchNorm2d             | 256
# 504 | model.vision_module.layer2.5.conv3               | Conv2d                  | 65 K
# 505 | model.vision_module.layer2.5.bn3                 | BatchNorm2d             | 1 K
# 506 | model.vision_module.layer2.5.relu                | ReLU                    | 0
# 507 | model.vision_module.layer2.6                     | Bottleneck              | 280 K
# 508 | model.vision_module.layer2.6.conv1               | Conv2d                  | 65 K
# 509 | model.vision_module.layer2.6.bn1                 | BatchNorm2d             | 256
# 510 | model.vision_module.layer2.6.conv2               | Conv2d                  | 147 K
# 511 | model.vision_module.layer2.6.bn2                 | BatchNorm2d             | 256
# 512 | model.vision_module.layer2.6.conv3               | Conv2d                  | 65 K
# 513 | model.vision_module.layer2.6.bn3                 | BatchNorm2d             | 1 K
# 514 | model.vision_module.layer2.6.relu                | ReLU                    | 0
# 515 | model.vision_module.layer2.7                     | Bottleneck              | 280 K
# 516 | model.vision_module.layer2.7.conv1               | Conv2d                  | 65 K
# 517 | model.vision_module.layer2.7.bn1                 | BatchNorm2d             | 256
# 518 | model.vision_module.layer2.7.conv2               | Conv2d                  | 147 K
# 519 | model.vision_module.layer2.7.bn2                 | BatchNorm2d             | 256
# 520 | model.vision_module.layer2.7.conv3               | Conv2d                  | 65 K
# 521 | model.vision_module.layer2.7.bn3                 | BatchNorm2d             | 1 K
# 522 | model.vision_module.layer2.7.relu                | ReLU                    | 0
# 523 | model.vision_module.layer3                       | Sequential              | 40 M
# 524 | model.vision_module.layer3.0                     | Bottleneck              | 1 M
# 525 | model.vision_module.layer3.0.conv1               | Conv2d                  | 131 K
# 526 | model.vision_module.layer3.0.bn1                 | BatchNorm2d             | 512
# 527 | model.vision_module.layer3.0.conv2               | Conv2d                  | 589 K
# ...
# Epoch 2:  90%|████████▉ | 1325/1480 [09:37<01:07,  2.29it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  90%|████████▉ | 1326/1480 [09:37<01:07,  2.29it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  90%|████████▉ | 1327/1480 [09:38<01:06,  2.30it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  90%|████████▉ | 1328/1480 [09:38<01:06,  2.30it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  90%|████████▉ | 1329/1480 [09:38<01:05,  2.30it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  90%|████████▉ | 1330/1480 [09:38<01:05,  2.30it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  90%|████████▉ | 1331/1480 [09:39<01:04,  2.30it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  90%|█████████ | 1332/1480 [09:39<01:04,  2.30it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  90%|█████████ | 1333/1480 [09:39<01:03,  2.30it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  90%|█████████ | 1334/1480 [09:39<01:03,  2.30it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  90%|█████████ | 1335/1480 [09:40<01:02,  2.30it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  90%|█████████ | 1336/1480 [09:40<01:02,  2.30it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  90%|█████████ | 1337/1480 [09:40<01:02,  2.30it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  90%|█████████ | 1338/1480 [09:40<01:01,  2.30it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  90%|█████████ | 1339/1480 [09:40<01:01,  2.31it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  91%|█████████ | 1340/1480 [09:41<01:00,  2.31it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  91%|█████████ | 1341/1480 [09:41<01:00,  2.31it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  91%|█████████ | 1342/1480 [09:41<00:59,  2.31it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  91%|█████████ | 1343/1480 [09:41<00:59,  2.31it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  91%|█████████ | 1344/1480 [09:42<00:58,  2.31it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  91%|█████████ | 1345/1480 [09:42<00:58,  2.31it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  91%|█████████ | 1346/1480 [09:42<00:57,  2.31it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  91%|█████████ | 1347/1480 [09:42<00:57,  2.31it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  91%|█████████ | 1348/1480 [09:42<00:57,  2.31it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  91%|█████████ | 1349/1480 [09:43<00:56,  2.31it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  91%|█████████ | 1350/1480 [09:43<00:56,  2.31it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  91%|█████████▏| 1351/1480 [09:43<00:55,  2.32it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  91%|█████████▏| 1352/1480 [09:43<00:55,  2.32it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  91%|█████████▏| 1353/1480 [09:44<00:54,  2.32it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  91%|█████████▏| 1354/1480 [09:44<00:54,  2.32it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  92%|█████████▏| 1355/1480 [09:44<00:53,  2.32it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  92%|█████████▏| 1356/1480 [09:44<00:53,  2.32it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  92%|█████████▏| 1357/1480 [09:44<00:53,  2.32it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  92%|█████████▏| 1358/1480 [09:45<00:52,  2.32it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  92%|█████████▏| 1359/1480 [09:45<00:52,  2.32it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  92%|█████████▏| 1360/1480 [09:45<00:51,  2.32it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  92%|█████████▏| 1361/1480 [09:45<00:51,  2.32it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  92%|█████████▏| 1362/1480 [09:45<00:50,  2.32it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  92%|█████████▏| 1363/1480 [09:46<00:50,  2.32it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  92%|█████████▏| 1364/1480 [09:46<00:49,  2.33it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  92%|█████████▏| 1365/1480 [09:46<00:49,  2.33it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  92%|█████████▏| 1366/1480 [09:46<00:48,  2.33it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  92%|█████████▏| 1367/1480 [09:47<00:48,  2.33it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  92%|█████████▏| 1368/1480 [09:47<00:48,  2.33it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  92%|█████████▎| 1369/1480 [09:47<00:47,  2.33it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  93%|█████████▎| 1370/1480 [09:47<00:47,  2.33it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  93%|█████████▎| 1371/1480 [09:47<00:46,  2.33it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  93%|█████████▎| 1372/1480 [09:48<00:46,  2.33it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  93%|█████████▎| 1373/1480 [09:48<00:45,  2.33it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  93%|█████████▎| 1374/1480 [09:48<00:45,  2.33it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  93%|█████████▎| 1375/1480 [09:48<00:44,  2.34it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  93%|█████████▎| 1376/1480 [09:49<00:44,  2.34it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  93%|█████████▎| 1377/1480 [09:49<00:44,  2.34it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  93%|█████████▎| 1378/1480 [09:49<00:43,  2.34it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  93%|█████████▎| 1379/1480 [09:49<00:43,  2.34it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  93%|█████████▎| 1380/1480 [09:49<00:42,  2.34it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  93%|█████████▎| 1381/1480 [09:50<00:42,  2.34it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  93%|█████████▎| 1382/1480 [09:50<00:41,  2.34it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  93%|█████████▎| 1383/1480 [09:50<00:41,  2.34it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  94%|█████████▎| 1384/1480 [09:50<00:40,  2.34it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  94%|█████████▎| 1385/1480 [09:51<00:40,  2.34it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  94%|█████████▎| 1386/1480 [09:51<00:40,  2.34it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  94%|█████████▎| 1387/1480 [09:51<00:39,  2.34it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  94%|█████████▍| 1388/1480 [09:51<00:39,  2.35it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  94%|█████████▍| 1389/1480 [09:51<00:38,  2.35it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  94%|█████████▍| 1390/1480 [09:52<00:38,  2.35it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  94%|█████████▍| 1391/1480 [09:52<00:37,  2.35it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  94%|█████████▍| 1392/1480 [09:52<00:37,  2.35it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  94%|█████████▍| 1393/1480 [09:52<00:37,  2.35it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  94%|█████████▍| 1394/1480 [09:52<00:36,  2.35it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  94%|█████████▍| 1395/1480 [09:53<00:36,  2.35it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  94%|█████████▍| 1396/1480 [09:53<00:35,  2.35it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  94%|█████████▍| 1397/1480 [09:53<00:35,  2.35it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  94%|█████████▍| 1398/1480 [09:53<00:34,  2.35it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  95%|█████████▍| 1399/1480 [09:54<00:34,  2.36it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  95%|█████████▍| 1400/1480 [09:54<00:33,  2.36it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  95%|█████████▍| 1401/1480 [09:54<00:33,  2.36it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  95%|█████████▍| 1402/1480 [09:54<00:33,  2.36it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  95%|█████████▍| 1403/1480 [09:54<00:32,  2.36it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  95%|█████████▍| 1404/1480 [09:55<00:32,  2.36it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  95%|█████████▍| 1405/1480 [09:55<00:31,  2.36it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  95%|█████████▌| 1406/1480 [09:55<00:31,  2.36it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  95%|█████████▌| 1407/1480 [09:55<00:30,  2.36it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  95%|█████████▌| 1408/1480 [09:55<00:30,  2.36it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  95%|█████████▌| 1409/1480 [09:56<00:30,  2.36it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  95%|█████████▌| 1410/1480 [09:56<00:29,  2.36it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  95%|█████████▌| 1411/1480 [09:56<00:29,  2.36it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  95%|█████████▌| 1412/1480 [09:56<00:28,  2.37it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  95%|█████████▌| 1413/1480 [09:57<00:28,  2.37it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  96%|█████████▌| 1414/1480 [09:57<00:27,  2.37it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  96%|█████████▌| 1415/1480 [09:57<00:27,  2.37it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  96%|█████████▌| 1416/1480 [09:57<00:27,  2.37it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  96%|█████████▌| 1417/1480 [09:58<00:26,  2.37it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  96%|█████████▌| 1418/1480 [09:58<00:26,  2.37it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  96%|█████████▌| 1419/1480 [09:58<00:25,  2.37it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  96%|█████████▌| 1420/1480 [09:58<00:25,  2.37it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  96%|█████████▌| 1421/1480 [09:58<00:24,  2.37it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  96%|█████████▌| 1422/1480 [09:59<00:24,  2.37it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  96%|█████████▌| 1423/1480 [09:59<00:24,  2.37it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  96%|█████████▌| 1424/1480 [09:59<00:23,  2.38it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  96%|█████████▋| 1425/1480 [09:59<00:23,  2.38it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  96%|█████████▋| 1426/1480 [09:59<00:22,  2.38it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  96%|█████████▋| 1427/1480 [10:00<00:22,  2.38it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  96%|█████████▋| 1428/1480 [10:00<00:21,  2.38it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  97%|█████████▋| 1429/1480 [10:00<00:21,  2.38it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  97%|█████████▋| 1430/1480 [10:00<00:21,  2.38it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  97%|█████████▋| 1431/1480 [10:01<00:20,  2.38it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  97%|█████████▋| 1432/1480 [10:01<00:20,  2.38it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  97%|█████████▋| 1433/1480 [10:01<00:19,  2.38it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  97%|█████████▋| 1434/1480 [10:01<00:19,  2.38it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  97%|█████████▋| 1435/1480 [10:01<00:18,  2.38it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  97%|█████████▋| 1436/1480 [10:02<00:18,  2.38it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  97%|█████████▋| 1437/1480 [10:02<00:18,  2.39it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  97%|█████████▋| 1438/1480 [10:02<00:17,  2.39it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  97%|█████████▋| 1439/1480 [10:02<00:17,  2.39it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  97%|█████████▋| 1440/1480 [10:03<00:16,  2.39it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  97%|█████████▋| 1441/1480 [10:03<00:16,  2.39it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  97%|█████████▋| 1442/1480 [10:03<00:15,  2.39it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  98%|█████████▊| 1443/1480 [10:03<00:15,  2.39it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  98%|█████████▊| 1444/1480 [10:03<00:15,  2.39it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  98%|█████████▊| 1445/1480 [10:04<00:14,  2.39it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  98%|█████████▊| 1446/1480 [10:04<00:14,  2.39it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  98%|█████████▊| 1447/1480 [10:04<00:13,  2.39it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  98%|█████████▊| 1448/1480 [10:04<00:13,  2.39it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  98%|█████████▊| 1449/1480 [10:04<00:12,  2.40it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  98%|█████████▊| 1450/1480 [10:05<00:12,  2.40it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  98%|█████████▊| 1451/1480 [10:05<00:12,  2.40it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  98%|█████████▊| 1452/1480 [10:05<00:11,  2.40it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  98%|█████████▊| 1453/1480 [10:05<00:11,  2.40it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  98%|█████████▊| 1454/1480 [10:06<00:10,  2.40it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  98%|█████████▊| 1455/1480 [10:06<00:10,  2.40it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  98%|█████████▊| 1456/1480 [10:06<00:09,  2.40it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  98%|█████████▊| 1457/1480 [10:06<00:09,  2.40it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  99%|█████████▊| 1458/1480 [10:06<00:09,  2.40it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  99%|█████████▊| 1459/1480 [10:07<00:08,  2.40it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  99%|█████████▊| 1460/1480 [10:07<00:08,  2.40it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  99%|█████████▊| 1461/1480 [10:07<00:07,  2.40it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  99%|█████████▉| 1462/1480 [10:07<00:07,  2.41it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  99%|█████████▉| 1463/1480 [10:08<00:07,  2.41it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  99%|█████████▉| 1464/1480 [10:08<00:06,  2.41it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  99%|█████████▉| 1465/1480 [10:08<00:06,  2.41it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  99%|█████████▉| 1466/1480 [10:08<00:05,  2.41it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  99%|█████████▉| 1467/1480 [10:08<00:05,  2.41it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  99%|█████████▉| 1468/1480 [10:09<00:04,  2.41it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  99%|█████████▉| 1469/1480 [10:09<00:04,  2.41it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  99%|█████████▉| 1470/1480 [10:09<00:04,  2.41it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  99%|█████████▉| 1471/1480 [10:09<00:03,  2.41it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2:  99%|█████████▉| 1472/1480 [10:10<00:03,  2.41it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2: 100%|█████████▉| 1473/1480 [10:10<00:02,  2.41it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2: 100%|█████████▉| 1474/1480 [10:10<00:02,  2.41it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2: 100%|█████████▉| 1475/1480 [10:10<00:02,  2.42it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2: 100%|█████████▉| 1476/1480 [10:10<00:01,  2.42it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2: 100%|█████████▉| 1477/1480 [10:11<00:01,  2.42it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2: 100%|█████████▉| 1478/1480 [10:11<00:00,  2.42it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2: 100%|█████████▉| 1479/1480 [10:11<00:00,  2.42it/s, avg_val_loss=0.68, loss=0.041, v_num=1]
# Epoch 2: 100%|██████████| 1480/1480 [10:11<00:00,  2.42it/s, avg_val_loss=0.688, loss=0.041, v_num=1]
#
# Epoch 00001: avg_val_loss  was not in top 1
# Epoch 00002: early stopping
# Epoch 2: 100%|██████████| 1480/1480 [10:11<00:00,  2.42it/s, avg_val_loss=0.688, loss=0.041, v_num=1]

# %%
hateful_memes_model = hateful_memes_model.to("cpu")
test_dataset = hateful_memes_model._build_dataset(test_path)
submission_frame = pd.DataFrame(
    index=test_dataset.samples_frame.id,
    columns=["proba", "label", "truth"]
)
test_dataloader = torch.utils.data.DataLoader(
    test_dataset, 
    shuffle=False, 
    batch_size=hateful_memes_model.hparams.get("batch_size", 4), 
    num_workers=hateful_memes_model.hparams.get("num_workers", 16))
for batch in tqdm(test_dataloader, total=len(test_dataloader)):
    preds, _ = hateful_memes_model.model.eval().to("cpu")(
        batch["text"].cpu(), batch["image"].cpu()
    )
    submission_frame.loc[batch["id"], "proba"] = preds[:, 1].detach().numpy()
    submission_frame.loc[batch["id"], "label"] = preds.argmax(dim=1).detach().numpy()
    submission_frame.loc[batch["id"], "truth"] = batch["label"].detach().numpy()
submission_frame.proba = submission_frame.proba.astype(float)
submission_frame.label = submission_frame.label.astype(int)
submission_frame.truth = submission_frame.truth.astype(int)
submission_frame.to_csv(("model-outputs_02/preMetrics.csv"), index=True)
# Out:
# 100%|██████████| 229/229 [05:12<00:00,  1.37s/it]

# %%
# we should only have saved the best checkpoint
checkpoints = list(Path("model-outputs_02").glob("*.ckpt"))
assert len(checkpoints) == 1

checkpoints
# Out:
# [WindowsPath('model-outputs_02/epoch=0.ckpt')]

# %%
hateful_memes_model = HatefulMemesModel.load_from_checkpoint(
    checkpoints[0]
)
submission = hateful_memes_model.make_submission_frame(
    test_path
)
submission.head()
# Out:
# EarlyStopping mode auto is unknown, fallback to auto mode.
# EarlyStopping mode set to min for monitoring avg_val_loss.
#   0%|          | 0/229 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-16-d73d3d467f7e> in <module>
#       2     checkpoints[0]
#       3 )
# ----> 4 submission = hateful_memes_model.make_submission_frame(
#       5     test_path
#       6 )
#
# C:\Python38\lib\site-packages\torch\autograd\grad_mode.py in decorate_context(*args, **kwargs)
#      25         def decorate_context(*args, **kwargs):
#      26             with self.__class__():
# ---> 27                 return func(*args, **kwargs)
#      28         return cast(F, decorate_context)
#      29
#
# <ipython-input-12-70683c7e565b> in make_submission_frame(self, test_path)
#     271             num_workers=self.hparams.get("num_workers", 16))
#     272         for batch in tqdm(test_dataloader, total=len(test_dataloader)):
# --> 273             preds, _ = self.model.eval().to("cpu")(
#     274                 batch["text"], batch["image"]
#     275             )
#
# C:\Python38\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# <ipython-input-11-c14587d487c8> in forward(self, text, image, label)
#      28     def forward(self, text, image, label=None):
#      29         text_features = torch.nn.functional.relu(
# ---> 30             self.language_module(text)
#      31         )
#      32         image_features = torch.nn.functional.relu(
#
# C:\Python38\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# C:\Python38\lib\site-packages\torch\nn\modules\linear.py in forward(self, input)
#      92
#      93     def forward(self, input: Tensor) -> Tensor:
# ---> 94         return F.linear(input, self.weight, self.bias)
#      95
#      96     def extra_repr(self) -> str:
#
# C:\Python38\lib\site-packages\torch\nn\functional.py in linear(input, weight, bias)
#    1751     if has_torch_function_variadic(input, weight):
#    1752         return handle_torch_function(linear, (input, weight), input, weight, bias=bias)
# -> 1753     return torch._C._nn.linear(input, weight, bias)
#    1754
#    1755
#
# RuntimeError: Tensor for 'out' is on CPU, Tensor for argument #1 'self' is on CPU, but expected them to be on GPU (while checking arguments for addmm)

# %%
submission.groupby("label").proba.mean()

# %%
submission.label.value_counts()

# %%
submission.to_csv(("model-outputs_02/submission.csv"), index=True)
